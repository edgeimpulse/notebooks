# %% [markdown]
# [![Works with Edge Impulse](../.assets/images/ei-badge.svg)](http://edgeimpulse.com) [![Open in Google Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/edgeimpulse/notebooks/blob/main/notebooks/03-generate-keyword-spotting-dataset.ipynb)

# %% [markdown]
# # Use Google Text-To-Speech to generate a dataset for keyword spotting

# %% [markdown]
# ## 1. Obtain an API key from your project

# %%
import os
# Insert the path to your service account API key json file here, for google cloud
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '../jim-sandbox-369711-9493c9a29d62.json'
# Keyword or short sentence and label (e.g. 'hello world')
keyword = [
    {'string':' infineon','label':'infineon'},
    {'string':' arrow','label':'arrow'},
           ]
# Languages, remove as appropriate
# languages = [
#     'ar-XA', 'bn-IN',  'en-GB',  'fr-CA',
#     'en-US', 'es-ES',  'fi-FI',  'gu-IN',
#     'ja-JP', 'kn-IN',  'ml-IN',  'sv-SE',
#     'ta-IN', 'tr-TR',  'cs-CZ',  'de-DE',
#     'en-AU', 'en-IN',  'fr-FR',  'hi-IN',
#     'id-ID', 'it-IT',  'ko-KR',  'ru-RU',
#     'uk-UA', 'cmn-CN', 'cmn-TW', 'da-DK',
#     'el-GR', 'fil-PH', 'hu-HU',  'nb-NO',
#     'nl-NL', 'pt-PT',  'sk-SK',  'vi-VN',
#     'pl-PL', 'pt-BR',  'ca-ES',  'yue-HK',
#     'af-ZA', 'bg-BG',  'lv-LV',  'ro-RO',
#     'sr-RS', 'th-TH',  'te-IN',  'is-IS'
# ]
languages = [
    'en-GB',  'fr-CA',
    'en-US', 'es-ES',  'gu-IN',
    'ja-JP', 'kn-IN',  'ml-IN',  'sv-SE',
    'ta-IN', 'tr-TR',  'cs-CZ',  'de-DE',
    'en-AU', 'en-IN',  'fr-FR',  'hi-IN',
    'id-ID', 'it-IT',  'ko-KR',  'ru-RU',
    'uk-UA', 'cmn-CN', 'cmn-TW', 'da-DK',
    'el-GR', 'fil-PH', 'hu-HU',  'nb-NO',
    'nl-NL', 'pt-PT',  'sk-SK',  'vi-VN',
    'pl-PL', 'pt-BR',  'ca-ES',  'yue-HK',
    'af-ZA', 'bg-BG',  'lv-LV',  'ro-RO',
    'sr-RS', 'th-TH',  'te-IN',  'is-IS'
]
# Number of keywords to generate
count = 2
# Out length (default: 00:01)
out_length = 2
# Pitches to generate
pitches = [-2, 0, 2]
# Voice genders to use
genders = ["NEUTRAL", "FEMALE", "MALE"]
# Speaking rates to use
speakingRates = [0.9, 1, 1.1]

# %%
import shutil
import json
import time
from google.cloud import texttospeech

all_opts = []
for p in pitches:
    for g in genders:
        for l in languages:
            for s in speakingRates:
                for kw in keyword:
                    all_opts.append({
                            "pitch": p,
                            "gender": g,
                            "language": l,
                            "speakingRate": s,
                            "text": kw['string'],
                            "label": kw['label']
                        })

if len(all_opts) > count:
    selectEvery = len(all_opts) // count
    selectNext = 0
    all_opts = [all_opts[ix] for ix in range(len(all_opts)) if ix > selectNext and (selectNext := selectNext + selectEvery) or True]

if os.path.exists('out-wav'):
    shutil.rmtree('out-wav')
os.makedirs('out-wav', exist_ok=True)

downloaded_files = []

# Instantiates a client
client = texttospeech.TextToSpeechClient()

ix = 0
for o in all_opts:
    ix += 1
    # Set the text input to be synthesized
    synthesis_input = texttospeech.SynthesisInput(text=o['text'])
    # Build the voice request
    voice = texttospeech.VoiceSelectionParams(
        language_code=o['language'],
        ssml_gender=o['gender']
    )
    # Select the type of audio file you want returned
    audio_config = texttospeech.AudioConfig(
        audio_encoding=texttospeech.AudioEncoding.LINEAR16,
        pitch=o['pitch'],
        speaking_rate=o['speakingRate'],
        sample_rate_hertz=16000
    )
    # Perform the text-to-speech request on the text input with the selected
    # voice parameters and audio file type
    

    wav_file_name = f"out-wav/{o['label']}.{o['language']}-{o['gender']}-{o['pitch']}-{o['speakingRate']}.tts.wav"

    if not os.path.exists(wav_file_name):
        print(f"[{ix}/{len(all_opts)}] Text-to-speeching...")
        response = client.synthesize_speech(
            input=synthesis_input, voice=voice, audio_config=audio_config
        )
        with open(wav_file_name, "wb") as f:
            f.write(response.audio_content)
        has_hit_api = True

    downloaded_files.append({
        "path": str(wav_file_name),
        "label": o['label'],
        "category": "split",
        "metadata": {
            "pitch": o['pitch'],
            "gender": o['gender'],
            "language": o['language'],
            "speakingRate": o['speakingRate'],
            "text": o['text'],
            "imported_from": "Google Cloud TTS"
        }
    })

    if has_hit_api:
        time.sleep(2)

print("Done text-to-speeching")
print("")

input_file = os.path.join(os.path.join(os.path.sep, 'tmp', 'ei-s3-sync-'), 'input.json')
os.makedirs(input_file.parent, exist_ok=True)

info_file = {
    "version": 1,
    "files": downloaded_files
}

with open(input_file, "w") as f:
    json.dump(info_file, f)
# Out:
# [1/2430] Text-to-speeching...
# [2/2430] Text-to-speeching...
# [3/2430] Text-to-speeching...
# [4/2430] Text-to-speeching...
# [5/2430] Text-to-speeching...
# [6/2430] Text-to-speeching...
# [7/2430] Text-to-speeching...
# [8/2430] Text-to-speeching...
# [9/2430] Text-to-speeching...
# [10/2430] Text-to-speeching...
# [11/2430] Text-to-speeching...
# [12/2430] Text-to-speeching...
# [13/2430] Text-to-speeching...
# [14/2430] Text-to-speeching...
# [15/2430] Text-to-speeching...
# [16/2430] Text-to-speeching...
# [17/2430] Text-to-speeching...
# [18/2430] Text-to-speeching...
# [19/2430] Text-to-speeching...
# [20/2430] Text-to-speeching...
# [21/2430] Text-to-speeching...
# [22/2430] Text-to-speeching...
# [23/2430] Text-to-speeching...
# [24/2430] Text-to-speeching...
# [25/2430] Text-to-speeching...
# [26/2430] Text-to-speeching...
# [27/2430] Text-to-speeching...
# [28/2430] Text-to-speeching...
# [29/2430] Text-to-speeching...
# [30/2430] Text-to-speeching...
# [31/2430] Text-to-speeching...
# [32/2430] Text-to-speeching...
# [33/2430] Text-to-speeching...
# [34/2430] Text-to-speeching...
# [35/2430] Text-to-speeching...
# [36/2430] Text-to-speeching...
# [37/2430] Text-to-speeching...
# [38/2430] Text-to-speeching...
# [39/2430] Text-to-speeching...
# [40/2430] Text-to-speeching...
# [41/2430] Text-to-speeching...
# [42/2430] Text-to-speeching...
# [43/2430] Text-to-speeching...
# [44/2430] Text-to-speeching...
# [45/2430] Text-to-speeching...
# [46/2430] Text-to-speeching...
# [47/2430] Text-to-speeching...
# [48/2430] Text-to-speeching...
# [49/2430] Text-to-speeching...
# [50/2430] Text-to-speeching...
# [51/2430] Text-to-speeching...
# [52/2430] Text-to-speeching...
# [53/2430] Text-to-speeching...
# [54/2430] Text-to-speeching...
# [55/2430] Text-to-speeching...
# [56/2430] Text-to-speeching...
# [57/2430] Text-to-speeching...
# [58/2430] Text-to-speeching...
# [59/2430] Text-to-speeching...
# [60/2430] Text-to-speeching...
# [61/2430] Text-to-speeching...
# [62/2430] Text-to-speeching...
# [63/2430] Text-to-speeching...
# [64/2430] Text-to-speeching...
# [65/2430] Text-to-speeching...
# [66/2430] Text-to-speeching...
# [67/2430] Text-to-speeching...
# [68/2430] Text-to-speeching...
# [69/2430] Text-to-speeching...
# [70/2430] Text-to-speeching...
# [71/2430] Text-to-speeching...
# [72/2430] Text-to-speeching...
# [73/2430] Text-to-speeching...
# [74/2430] Text-to-speeching...
# [75/2430] Text-to-speeching...
# [76/2430] Text-to-speeching...
# [77/2430] Text-to-speeching...
# [78/2430] Text-to-speeching...
# [79/2430] Text-to-speeching...
# [80/2430] Text-to-speeching...
# [81/2430] Text-to-speeching...
# [82/2430] Text-to-speeching...
# [83/2430] Text-to-speeching...
# [84/2430] Text-to-speeching...
# [85/2430] Text-to-speeching...
# [86/2430] Text-to-speeching...
# [87/2430] Text-to-speeching...
# [88/2430] Text-to-speeching...
# [89/2430] Text-to-speeching...
# [90/2430] Text-to-speeching...
# [91/2430] Text-to-speeching...
# [92/2430] Text-to-speeching...
# [93/2430] Text-to-speeching...
# [94/2430] Text-to-speeching...
# [95/2430] Text-to-speeching...
# [96/2430] Text-to-speeching...
# [97/2430] Text-to-speeching...
# [98/2430] Text-to-speeching...
# [99/2430] Text-to-speeching...
# [100/2430] Text-to-speeching...
# [101/2430] Text-to-speeching...
# [102/2430] Text-to-speeching...
# [103/2430] Text-to-speeching...
# [104/2430] Text-to-speeching...
# [105/2430] Text-to-speeching...
# [106/2430] Text-to-speeching...
# [107/2430] Text-to-speeching...
# [108/2430] Text-to-speeching...
# [109/2430] Text-to-speeching...
# [110/2430] Text-to-speeching...
# [111/2430] Text-to-speeching...
# [112/2430] Text-to-speeching...
# [113/2430] Text-to-speeching...
# [114/2430] Text-to-speeching...
# [115/2430] Text-to-speeching...
# [116/2430] Text-to-speeching...
# [117/2430] Text-to-speeching...
# [118/2430] Text-to-speeching...
# [119/2430] Text-to-speeching...
# [120/2430] Text-to-speeching...
# [121/2430] Text-to-speeching...
# [122/2430] Text-to-speeching...
# [123/2430] Text-to-speeching...
# [124/2430] Text-to-speeching...
# [125/2430] Text-to-speeching...
# [126/2430] Text-to-speeching...
# [127/2430] Text-to-speeching...
# [128/2430] Text-to-speeching...
# [129/2430] Text-to-speeching...
# [130/2430] Text-to-speeching...
# [131/2430] Text-to-speeching...
# [132/2430] Text-to-speeching...
# [133/2430] Text-to-speeching...
# [134/2430] Text-to-speeching...
# [135/2430] Text-to-speeching...
# [136/2430] Text-to-speeching...
# [137/2430] Text-to-speeching...
# [138/2430] Text-to-speeching...
# [139/2430] Text-to-speeching...
# [140/2430] Text-to-speeching...
# [141/2430] Text-to-speeching...
# [142/2430] Text-to-speeching...
# [143/2430] Text-to-speeching...
# [144/2430] Text-to-speeching...
# [145/2430] Text-to-speeching...
# [146/2430] Text-to-speeching...
# [147/2430] Text-to-speeching...
# [148/2430] Text-to-speeching...
# [149/2430] Text-to-speeching...
# [150/2430] Text-to-speeching...
# [151/2430] Text-to-speeching...
# [152/2430] Text-to-speeching...
# [153/2430] Text-to-speeching...
# [154/2430] Text-to-speeching...
# [155/2430] Text-to-speeching...
# [156/2430] Text-to-speeching...
# [157/2430] Text-to-speeching...
# [158/2430] Text-to-speeching...
# [159/2430] Text-to-speeching...
# [160/2430] Text-to-speeching...
# [161/2430] Text-to-speeching...
# [162/2430] Text-to-speeching...
# [163/2430] Text-to-speeching...
# [164/2430] Text-to-speeching...
# [165/2430] Text-to-speeching...
# [166/2430] Text-to-speeching...
# [167/2430] Text-to-speeching...
# [168/2430] Text-to-speeching...
# [169/2430] Text-to-speeching...
# [170/2430] Text-to-speeching...
# [171/2430] Text-to-speeching...
# [172/2430] Text-to-speeching...
# [173/2430] Text-to-speeching...
# [174/2430] Text-to-speeching...
# [175/2430] Text-to-speeching...
# [176/2430] Text-to-speeching...
# [177/2430] Text-to-speeching...
# [178/2430] Text-to-speeching...
# [179/2430] Text-to-speeching...
# [180/2430] Text-to-speeching...
# [181/2430] Text-to-speeching...
# [182/2430] Text-to-speeching...
# [183/2430] Text-to-speeching...
# [184/2430] Text-to-speeching...
# [185/2430] Text-to-speeching...
# [186/2430] Text-to-speeching...
# [187/2430] Text-to-speeching...
# [188/2430] Text-to-speeching...
# [189/2430] Text-to-speeching...
# [190/2430] Text-to-speeching...
# [191/2430] Text-to-speeching...
# [192/2430] Text-to-speeching...
# [193/2430] Text-to-speeching...
# [194/2430] Text-to-speeching...
# [195/2430] Text-to-speeching...
# [196/2430] Text-to-speeching...
# [197/2430] Text-to-speeching...
# [198/2430] Text-to-speeching...
# [199/2430] Text-to-speeching...
# [200/2430] Text-to-speeching...
# [201/2430] Text-to-speeching...
# [202/2430] Text-to-speeching...
# [203/2430] Text-to-speeching...
# [204/2430] Text-to-speeching...
# [205/2430] Text-to-speeching...
# [206/2430] Text-to-speeching...
# [207/2430] Text-to-speeching...
# [208/2430] Text-to-speeching...
# [209/2430] Text-to-speeching...
# [210/2430] Text-to-speeching...
# [211/2430] Text-to-speeching...
# [212/2430] Text-to-speeching...
# [213/2430] Text-to-speeching...
# [214/2430] Text-to-speeching...
# [215/2430] Text-to-speeching...
# [216/2430] Text-to-speeching...
# [217/2430] Text-to-speeching...
# [218/2430] Text-to-speeching...
# [219/2430] Text-to-speeching...
# [220/2430] Text-to-speeching...
# [221/2430] Text-to-speeching...
# [222/2430] Text-to-speeching...
# [223/2430] Text-to-speeching...
# [224/2430] Text-to-speeching...
# [225/2430] Text-to-speeching...
# [226/2430] Text-to-speeching...
# [227/2430] Text-to-speeching...
# [228/2430] Text-to-speeching...
# [229/2430] Text-to-speeching...
# [230/2430] Text-to-speeching...
# [231/2430] Text-to-speeching...
# [232/2430] Text-to-speeching...
# [233/2430] Text-to-speeching...
# [234/2430] Text-to-speeching...
# [235/2430] Text-to-speeching...
# [236/2430] Text-to-speeching...
# [237/2430] Text-to-speeching...
# [238/2430] Text-to-speeching...
# [239/2430] Text-to-speeching...
# [240/2430] Text-to-speeching...
# [241/2430] Text-to-speeching...
# [242/2430] Text-to-speeching...
# [243/2430] Text-to-speeching...
# [244/2430] Text-to-speeching...
# [245/2430] Text-to-speeching...
# [246/2430] Text-to-speeching...
# [247/2430] Text-to-speeching...
# [248/2430] Text-to-speeching...
# [249/2430] Text-to-speeching...
# [250/2430] Text-to-speeching...
# [251/2430] Text-to-speeching...
# [252/2430] Text-to-speeching...
# [253/2430] Text-to-speeching...
# [254/2430] Text-to-speeching...
# [255/2430] Text-to-speeching...
# [256/2430] Text-to-speeching...
# [257/2430] Text-to-speeching...
# [258/2430] Text-to-speeching...
# [259/2430] Text-to-speeching...
# [260/2430] Text-to-speeching...
# [261/2430] Text-to-speeching...
# [262/2430] Text-to-speeching...
# [263/2430] Text-to-speeching...
# [264/2430] Text-to-speeching...
# [265/2430] Text-to-speeching...
# [266/2430] Text-to-speeching...
# [267/2430] Text-to-speeching...
# [268/2430] Text-to-speeching...
# [269/2430] Text-to-speeching...
# [270/2430] Text-to-speeching...
# [271/2430] Text-to-speeching...
# [272/2430] Text-to-speeching...
# [273/2430] Text-to-speeching...
# [274/2430] Text-to-speeching...
# [275/2430] Text-to-speeching...
# [276/2430] Text-to-speeching...
# [277/2430] Text-to-speeching...
# [278/2430] Text-to-speeching...
# [279/2430] Text-to-speeching...
# [280/2430] Text-to-speeching...
# [281/2430] Text-to-speeching...
# [282/2430] Text-to-speeching...
# [283/2430] Text-to-speeching...
# [284/2430] Text-to-speeching...
# [285/2430] Text-to-speeching...
# [286/2430] Text-to-speeching...
# [287/2430] Text-to-speeching...
# [288/2430] Text-to-speeching...
# [289/2430] Text-to-speeching...
# [290/2430] Text-to-speeching...
# [291/2430] Text-to-speeching...
# [292/2430] Text-to-speeching...
# [293/2430] Text-to-speeching...
# [294/2430] Text-to-speeching...
# [295/2430] Text-to-speeching...
# [296/2430] Text-to-speeching...
# [297/2430] Text-to-speeching...
# [298/2430] Text-to-speeching...
# [299/2430] Text-to-speeching...
# [300/2430] Text-to-speeching...
# [301/2430] Text-to-speeching...
# [302/2430] Text-to-speeching...
# [303/2430] Text-to-speeching...
# [304/2430] Text-to-speeching...
# [305/2430] Text-to-speeching...
# [306/2430] Text-to-speeching...
# [307/2430] Text-to-speeching...
# [308/2430] Text-to-speeching...
# [309/2430] Text-to-speeching...
# [310/2430] Text-to-speeching...
# [311/2430] Text-to-speeching...
# [312/2430] Text-to-speeching...
# [313/2430] Text-to-speeching...
# [314/2430] Text-to-speeching...
# [315/2430] Text-to-speeching...
# [316/2430] Text-to-speeching...
# [317/2430] Text-to-speeching...
# [318/2430] Text-to-speeching...
# [319/2430] Text-to-speeching...
# [320/2430] Text-to-speeching...
# [321/2430] Text-to-speeching...
# [322/2430] Text-to-speeching...
# [323/2430] Text-to-speeching...
# [324/2430] Text-to-speeching...
# [325/2430] Text-to-speeching...
# [326/2430] Text-to-speeching...
# [327/2430] Text-to-speeching...
# [328/2430] Text-to-speeching...
# [329/2430] Text-to-speeching...
# [330/2430] Text-to-speeching...
# [331/2430] Text-to-speeching...
# [332/2430] Text-to-speeching...
# [333/2430] Text-to-speeching...
# [334/2430] Text-to-speeching...
# [335/2430] Text-to-speeching...
# [336/2430] Text-to-speeching...
# [337/2430] Text-to-speeching...
# [338/2430] Text-to-speeching...
# [339/2430] Text-to-speeching...
# [340/2430] Text-to-speeching...
# [341/2430] Text-to-speeching...
# [342/2430] Text-to-speeching...
# [343/2430] Text-to-speeching...
# [344/2430] Text-to-speeching...
# [345/2430] Text-to-speeching...
# [346/2430] Text-to-speeching...
# [347/2430] Text-to-speeching...
# [348/2430] Text-to-speeching...
# [349/2430] Text-to-speeching...
# [350/2430] Text-to-speeching...
# [351/2430] Text-to-speeching...
# [352/2430] Text-to-speeching...
# [353/2430] Text-to-speeching...
# [354/2430] Text-to-speeching...
# [355/2430] Text-to-speeching...
# [356/2430] Text-to-speeching...
# [357/2430] Text-to-speeching...
# [358/2430] Text-to-speeching...
# [359/2430] Text-to-speeching...
# [360/2430] Text-to-speeching...
# [361/2430] Text-to-speeching...
# [362/2430] Text-to-speeching...
# [363/2430] Text-to-speeching...
# [364/2430] Text-to-speeching...
# [365/2430] Text-to-speeching...
# [366/2430] Text-to-speeching...
# [367/2430] Text-to-speeching...
# [368/2430] Text-to-speeching...
# [369/2430] Text-to-speeching...
# [370/2430] Text-to-speeching...
# [371/2430] Text-to-speeching...
# [372/2430] Text-to-speeching...
# [373/2430] Text-to-speeching...
# [374/2430] Text-to-speeching...
# [375/2430] Text-to-speeching...
# [376/2430] Text-to-speeching...
# [377/2430] Text-to-speeching...
# [378/2430] Text-to-speeching...
# [379/2430] Text-to-speeching...
# [380/2430] Text-to-speeching...
# [381/2430] Text-to-speeching...
# [382/2430] Text-to-speeching...
# [383/2430] Text-to-speeching...
# [384/2430] Text-to-speeching...
# [385/2430] Text-to-speeching...
# [386/2430] Text-to-speeching...
# [387/2430] Text-to-speeching...
# [388/2430] Text-to-speeching...
# [389/2430] Text-to-speeching...
# [390/2430] Text-to-speeching...
# [391/2430] Text-to-speeching...
# [392/2430] Text-to-speeching...
# [393/2430] Text-to-speeching...
# [394/2430] Text-to-speeching...
# [395/2430] Text-to-speeching...
# [396/2430] Text-to-speeching...
# [397/2430] Text-to-speeching...
# [398/2430] Text-to-speeching...
# [399/2430] Text-to-speeching...
# [400/2430] Text-to-speeching...
# [401/2430] Text-to-speeching...
# [402/2430] Text-to-speeching...
# [403/2430] Text-to-speeching...
# [404/2430] Text-to-speeching...
# [405/2430] Text-to-speeching...
# [406/2430] Text-to-speeching...
# [407/2430] Text-to-speeching...
# [408/2430] Text-to-speeching...
# [409/2430] Text-to-speeching...
# [410/2430] Text-to-speeching...
# [411/2430] Text-to-speeching...
# [412/2430] Text-to-speeching...
# [413/2430] Text-to-speeching...
# [414/2430] Text-to-speeching...
# [415/2430] Text-to-speeching...
# [416/2430] Text-to-speeching...
# [417/2430] Text-to-speeching...
# [418/2430] Text-to-speeching...
# [419/2430] Text-to-speeching...
# [420/2430] Text-to-speeching...
# [421/2430] Text-to-speeching...
# [422/2430] Text-to-speeching...
# [423/2430] Text-to-speeching...
# [424/2430] Text-to-speeching...
# [425/2430] Text-to-speeching...
# [426/2430] Text-to-speeching...
# [427/2430] Text-to-speeching...
# [428/2430] Text-to-speeching...
# [429/2430] Text-to-speeching...
# [430/2430] Text-to-speeching...
# [431/2430] Text-to-speeching...
# [432/2430] Text-to-speeching...
# [433/2430] Text-to-speeching...
# [434/2430] Text-to-speeching...
# [435/2430] Text-to-speeching...
# [436/2430] Text-to-speeching...
# [437/2430] Text-to-speeching...
# [438/2430] Text-to-speeching...
# [439/2430] Text-to-speeching...
# [440/2430] Text-to-speeching...
# [441/2430] Text-to-speeching...
# [442/2430] Text-to-speeching...
# [443/2430] Text-to-speeching...
# [444/2430] Text-to-speeching...
# [445/2430] Text-to-speeching...
# [446/2430] Text-to-speeching...
# [447/2430] Text-to-speeching...
# [448/2430] Text-to-speeching...
# [449/2430] Text-to-speeching...
# [450/2430] Text-to-speeching...
# [451/2430] Text-to-speeching...
# [452/2430] Text-to-speeching...
# [453/2430] Text-to-speeching...
# [454/2430] Text-to-speeching...
# [455/2430] Text-to-speeching...
# [456/2430] Text-to-speeching...
# [457/2430] Text-to-speeching...
# [458/2430] Text-to-speeching...
# [459/2430] Text-to-speeching...
# [460/2430] Text-to-speeching...
# [461/2430] Text-to-speeching...
# [462/2430] Text-to-speeching...
# [463/2430] Text-to-speeching...
# [464/2430] Text-to-speeching...
# [465/2430] Text-to-speeching...
# [466/2430] Text-to-speeching...
# [467/2430] Text-to-speeching...
# [468/2430] Text-to-speeching...
# [469/2430] Text-to-speeching...
# [470/2430] Text-to-speeching...
# [471/2430] Text-to-speeching...
# [472/2430] Text-to-speeching...
# [473/2430] Text-to-speeching...
# [474/2430] Text-to-speeching...
# [475/2430] Text-to-speeching...
# [476/2430] Text-to-speeching...
# [477/2430] Text-to-speeching...
# [478/2430] Text-to-speeching...
# [479/2430] Text-to-speeching...
# [480/2430] Text-to-speeching...
# [481/2430] Text-to-speeching...
# [482/2430] Text-to-speeching...
# [483/2430] Text-to-speeching...
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/google/api_core/grpc_helpers.py:72, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      71 try:
# ---> 72     return callable_(*args, **kwargs)
#      73 except grpc.RpcError as exc:
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/grpc/_channel.py:946, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     944 state, call, = self._blocking(request, timeout, metadata, credentials,
#     945                               wait_for_ready, compression)
# --> 946 return _end_unary_response_blocking(state, call, False, None)
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/grpc/_channel.py:849, in _end_unary_response_blocking(state, call, with_call, deadline)
#     848 else:
# --> 849     raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.INTERNAL
# 	details = "Internal error encountered."
# 	debug_error_string = "UNKNOWN:Error received from peer ipv4:142.250.200.10:443 {grpc_message:"Internal error encountered.", grpc_status:13, created_time:"2023-02-28T15:51:29.919124+00:00"}"
# >
#
# The above exception was the direct cause of the following exception:
#
# InternalServerError                       Traceback (most recent call last)
# Cell In [54], line 61
#      59 if not os.path.exists(wav_file_name):
#      60     print(f"[{ix}/{len(all_opts)}] Text-to-speeching...")
# ---> 61     response = client.synthesize_speech(
#      62         input=synthesis_input, voice=voice, audio_config=audio_config
#      63     )
#      64     with open(wav_file_name, "wb") as f:
#      65         f.write(response.audio_content)
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/google/cloud/texttospeech_v1/services/text_to_speech/client.py:663, in TextToSpeechClient.synthesize_speech(self, request, input, voice, audio_config, retry, timeout, metadata)
#     660 rpc = self._transport._wrapped_methods[self._transport.synthesize_speech]
#     662 # Send the request.
# --> 663 response = rpc(
#     664     request,
#     665     retry=retry,
#     666     timeout=timeout,
#     667     metadata=metadata,
#     668 )
#     670 # Done; return the response.
#     671 return response
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py:113, in _GapicCallable.__call__(self, timeout, retry, *args, **kwargs)
#     110     metadata.extend(self._metadata)
#     111     kwargs["metadata"] = metadata
# --> 113 return wrapped_func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/google/api_core/grpc_helpers.py:74, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      72     return callable_(*args, **kwargs)
#      73 except grpc.RpcError as exc:
# ---> 74     raise exceptions.from_grpc_error(exc) from exc
#
# InternalServerError: 500 Internal error encountered.

# %%
import os
import requests
import io
import random
import pydub
from pydub import AudioSegment

# Set parameters
voice_dir = 'out-wav'
# Creative commons background noise from freesound.org:https://freesound.org/people/Astounded/sounds/483561/
noise_url = 'https://cdn.freesound.org/previews/483/483561_10201334-lq.ogg'
output_dir = 'out-noisy'
num_copies = 3  # Number of noisy copies to create for each input sample
max_noise_level = -6  # Maximum noise level to add in dBFS (negative value)

# Check if output directory exists and create it if it doesn't
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Download background noise file
response = requests.get(noise_url)
response.raise_for_status()
noise_audio = AudioSegment.from_file(io.BytesIO(response.content), format='ogg')

# Loop through voice samples in directory
for file_name in os.listdir(voice_dir):
    if file_name.endswith('.wav'):
        # Load voice sample
        voice_file = os.path.join(voice_dir, file_name)
        voice_audio = AudioSegment.from_file(voice_file)

        for i in range(num_copies):
            # Select random section of noise and random noise level
            start_time = random.randint(0, len(noise_audio) - len(voice_audio))
            end_time = start_time + len(voice_audio)
            noise_level = random.uniform(max_noise_level, 0)

            # Extract selected section of noise and adjust volume
            noise_segment = noise_audio[start_time:end_time]
            noise_segment = noise_segment - abs(noise_level)

            # Mix voice sample with noise segment
            mixed_audio = voice_audio.overlay(noise_segment)

            # Create new file name for mixed audio
            output_file = file_name.split('.wav')[0] + f'_mixed_{i}.wav'
            output_path = os.path.join(output_dir, output_file)

            # Save mixed audio to file
            mixed_audio.export(output_path, format='wav')

            print(f'Saved mixed audio to {output_path}')
# Out:
# Saved mixed audio to out-noisy/helloworld.bn-IN-FEMALE--10-1.25.tts_mixed_0.wav
# Saved mixed audio to out-noisy/helloworld.bn-IN-FEMALE--10-1.25.tts_mixed_1.wav
# Saved mixed audio to out-noisy/helloworld.bn-IN-FEMALE--10-1.25.tts_mixed_2.wav
# Saved mixed audio to out-noisy/helloworld.en-GB-FEMALE--10-1.tts_mixed_0.wav
# Saved mixed audio to out-noisy/helloworld.en-GB-FEMALE--10-1.tts_mixed_1.wav
# Saved mixed audio to out-noisy/helloworld.en-GB-FEMALE--10-1.tts_mixed_2.wav
# Saved mixed audio to out-noisy/helloworld.en-GB-FEMALE--10-1.25.tts_mixed_0.wav
# Saved mixed audio to out-noisy/helloworld.en-GB-FEMALE--10-1.25.tts_mixed_1.wav
# Saved mixed audio to out-noisy/helloworld.en-GB-FEMALE--10-1.25.tts_mixed_2.wav
# Saved mixed audio to out-noisy/helloworld.bn-IN-FEMALE--10-1.tts_mixed_0.wav
# Saved mixed audio to out-noisy/helloworld.bn-IN-FEMALE--10-1.tts_mixed_1.wav
# Saved mixed audio to out-noisy/helloworld.bn-IN-FEMALE--10-1.tts_mixed_2.wav
# Saved mixed audio to out-noisy/helloworld.ar-XA-FEMALE--10-1.tts_mixed_0.wav
# Saved mixed audio to out-noisy/helloworld.ar-XA-FEMALE--10-1.tts_mixed_1.wav
# Saved mixed audio to out-noisy/helloworld.ar-XA-FEMALE--10-1.tts_mixed_2.wav
# Saved mixed audio to out-noisy/helloworld.bn-IN-FEMALE--10-0.75.tts_mixed_0.wav
# Saved mixed audio to out-noisy/helloworld.bn-IN-FEMALE--10-0.75.tts_mixed_1.wav
# Saved mixed audio to out-noisy/helloworld.bn-IN-FEMALE--10-0.75.tts_mixed_2.wav
# Saved mixed audio to out-noisy/helloworld.en-GB-FEMALE--10-0.75.tts_mixed_0.wav
# Saved mixed audio to out-noisy/helloworld.en-GB-FEMALE--10-0.75.tts_mixed_1.wav
# Saved mixed audio to out-noisy/helloworld.en-GB-FEMALE--10-0.75.tts_mixed_2.wav
# Saved mixed audio to out-noisy/helloworld.ar-XA-FEMALE--10-1.25.tts_mixed_0.wav
# Saved mixed audio to out-noisy/helloworld.ar-XA-FEMALE--10-1.25.tts_mixed_1.wav
# Saved mixed audio to out-noisy/helloworld.ar-XA-FEMALE--10-1.25.tts_mixed_2.wav
# Saved mixed audio to out-noisy/helloworld.fr-CA-FEMALE--10-0.75.tts_mixed_0.wav
# Saved mixed audio to out-noisy/helloworld.fr-CA-FEMALE--10-0.75.tts_mixed_1.wav
# Saved mixed audio to out-noisy/helloworld.fr-CA-FEMALE--10-0.75.tts_mixed_2.wav
# Saved mixed audio to out-noisy/helloworld.ar-XA-FEMALE--10-0.75.tts_mixed_0.wav
# Saved mixed audio to out-noisy/helloworld.ar-XA-FEMALE--10-0.75.tts_mixed_1.wav
# Saved mixed audio to out-noisy/helloworld.ar-XA-FEMALE--10-0.75.tts_mixed_2.wav

# %%
import requests
import os
import random
from pydub import AudioSegment

# Creative commons background noise from freesound.org:https://freesound.org/people/Astounded/sounds/483561/
sound_url = 'https://cdn.freesound.org/previews/483/483561_10201334-lq.ogg'
output_file = 'sound_file.ogg'

# Download sound file
response = requests.get(sound_url)
response.raise_for_status()
sound_data = response.content

# Save sound file to disk
with open(output_file, 'wb') as f:
    f.write(sound_data)

print(f'Saved sound file to {output_file}')

# Set parameters
input_folder = 'out-wav'
output_folder = 'out-noisy'
db_reduction = 20  # dB reduction of background noise relative to voice sample
num_copies = 3  # number of noisy copies to create for each input file

# Load background noise
background_noise = AudioSegment.from_file(output_file)

# Iterate over input files
for filename in os.listdir(input_folder):
    if filename.endswith('.wav'):
        # Load voice sample
        voice_sample = AudioSegment.from_file(os.path.join(input_folder, filename))

        # Randomly select start point for background noise
        start_time = random.randint(0, len(background_noise) - len(voice_sample))

        # Extract noise segment with same length as voice sample
        noise_segment = background_noise[start_time:start_time + len(voice_sample)]

        # Reduce noise level relative to voice sample
        noise_segment = noise_segment - db_reduction

        # Mix noise into voice sample
        for i in range(num_copies):
            # Add noise to voice sample
            noisy_sample = voice_sample.overlay(noise_segment)

            # Save noisy sample to output folder
            output_filename = f'{os.path.splitext(filename)[0]}_noisy_{i+1}.wav'
            output_path = os.path.join(output_folder, output_filename)
            noisy_sample.export(output_path, format='wav')
# Out:
# Saved sound file to sound_file.ogg
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [27], line 53
#      51 output_filename = f'{os.path.splitext(filename)[0]}_noisy_{i+1}.wav'
#      52 output_path = os.path.join(output_folder, output_filename)
# ---> 53 noisy_sample.export(output_path, format='wav')
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/pydub/audio_segment.py:867, in AudioSegment.export(self, out_f, format, codec, bitrate, parameters, tags, id3v2_version, cover)
#     861 if format == "raw" and (codec is not None or parameters is not None):
#     862     raise AttributeError(
#     863             'Can not invoke ffmpeg when export format is "raw"; '
#     864             'specify an ffmpeg raw format like format="s16le" instead '
#     865             'or call export(format="raw") with no codec or parameters')
# --> 867 out_f, _ = _fd_or_path_or_tempfile(out_f, 'wb+')
#     868 out_f.seek(0)
#     870 if format == "raw":
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/pydub/utils.py:60, in _fd_or_path_or_tempfile(fd, mode, tempfile)
#      57     close_fd = True
#      59 if isinstance(fd, basestring):
# ---> 60     fd = open(fd, mode=mode)
#      61     close_fd = True
#      63 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'out-noisy/helloworld.bn-IN-FEMALE--10-1.25.tts_noisy_1.wav'

# %%
import shutil
import json
import subprocess
import time
from google.cloud import texttospeech
import os
import requests
import io
import random
import pydub
from pydub import AudioSegment

# Set parameters
voice_dir = 'out-wav'
# Creative commons background noise from freesound.org:https://freesound.org/people/Astounded/sounds/483561/
noise_url = 'https://cdn.freesound.org/previews/483/483561_10201334-lq.ogg'
output_folder = 'out-noisy'
num_copies = 3  # Number of noisy copies to create for each input sample
max_noise_level = -6  # Maximum noise level to add in dBFS (negative value)

# Check if output directory exists and create it if it doesn't
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    

# Download background noise file
response = requests.get(noise_url)
response.raise_for_status()
noise_audio = AudioSegment.from_file(io.BytesIO(response.content), format='ogg')


all_opts = []
for p in pitches:
    for g in genders:
        for l in languages:
            for s in speakingRates:
                for kw in keyword:
                    all_opts.append({
                            "pitch": p,
                            "gender": g,
                            "language": l,
                            "speakingRate": s,
                            "text": kw['string'],
                            "label": kw['label']
                        })

if len(all_opts) > count:
    selectEvery = len(all_opts) // count
    selectNext = 0
    all_opts = [all_opts[ix] for ix in range(len(all_opts)) if ix > selectNext and (selectNext := selectNext + selectEvery) or True]

# if os.path.exists(voice_dir):
#     shutil.rmtree(voice_dir)
# os.makedirs(voice_dir, exist_ok=True)
# Check if output directory exists and create it if it doesn't
if not os.path.exists(voice_dir):
    os.makedirs(voice_dir)
downloaded_files = []

# Instantiates a client
client = texttospeech.TextToSpeechClient()

ix = 0
for o in all_opts:
    ix += 1
    # Set the text input to be synthesized
    synthesis_input = texttospeech.SynthesisInput(text=o['text'])
    # Build the voice request
    voice = texttospeech.VoiceSelectionParams(
        language_code=o['language'],
        ssml_gender=o['gender']
    )
    # Select the type of audio file you want returned
    audio_config = texttospeech.AudioConfig(
        audio_encoding=texttospeech.AudioEncoding.LINEAR16,
        pitch=o['pitch'],
        speaking_rate=o['speakingRate'],
        sample_rate_hertz=16000
    )
    # Perform the text-to-speech request on the text input with the selected
    # voice parameters and audio file type
    

    wav_file_name = f"{voice_dir}/{o['label']}.{o['language']}-{o['gender']}-{o['pitch']}-{o['speakingRate']}.tts.wav"

    if not os.path.exists(wav_file_name):
        print(f"[{ix}/{len(all_opts)}] Text-to-speeching...")
        response = client.synthesize_speech(
            input=synthesis_input, voice=voice, audio_config=audio_config
        )
        with open(wav_file_name, "wb") as f:
            f.write(response.audio_content)
        has_hit_api = True
    else:
        print(f'skipping {wav_file_name}')
        has_hit_api = False

    # Load voice sample
    voice_audio = AudioSegment.from_file(wav_file_name)

    for i in range(num_copies):
        # Save noisy sample to output folder
        output_filename = f"{o['label']}.{o['language']}-{o['gender']}-{o['pitch']}-{o['speakingRate']}_noisy_{i+1}.wav"
        output_path = os.path.join(output_folder, output_filename)
        if not os.path.exists(output_path):
            # Select random section of noise and random noise level
            start_time = random.randint(0, len(noise_audio) - len(voice_audio))
            end_time = start_time + len(voice_audio)
            noise_level = random.uniform(max_noise_level, 0)

            # Extract selected section of noise and adjust volume
            noise_segment = noise_audio[start_time:end_time]
            noise_segment = noise_segment - abs(noise_level)

            # Mix voice sample with noise segment
            mixed_audio = voice_audio.overlay(noise_segment)
            # Save mixed audio to file
            mixed_audio.export(output_path, format='wav')

            print(f'Saved mixed audio to {output_path}')
        else:
            print(f'skipping {output_path}')
        downloaded_files.append({
            "path": str(output_filename),
            "label": o['label'],
            "category": "split",
            "metadata": {
                "pitch": str(['pitch']),
                "gender": str(o['gender']),
                "language": str(o['language']),
                "speakingRate": str(o['speakingRate']),
                "text": o['text'],
                "imported_from": "Google Cloud TTS"
            }
        })

    if has_hit_api:
        time.sleep(0.5)

print("Done text-to-speeching")
print("")

input_file = os.path.join(output_folder, 'input.json')
info_file = {
    "version": 1,
    "files": downloaded_files
}

with open(input_file, "w") as f:
    json.dump(info_file, f)
# Out:
# skipping out-wav/infineon.en-GB-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.en-GB-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.en-GB-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.en-GB-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.en-GB-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.en-GB-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.en-GB-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.en-GB-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.en-GB-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.en-GB-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.en-GB-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.en-GB-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.en-GB-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.en-GB-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.en-GB-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.en-GB-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.en-GB-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.en-GB-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.en-GB-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.en-GB-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.en-GB-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.en-GB-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.en-GB-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.en-GB-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.fr-CA-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.fr-CA-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.fr-CA-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.fr-CA-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.fr-CA-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.fr-CA-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.fr-CA-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.fr-CA-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.fr-CA-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.fr-CA-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.fr-CA-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.fr-CA-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.fr-CA-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.fr-CA-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.fr-CA-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.fr-CA-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.fr-CA-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.fr-CA-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.fr-CA-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.fr-CA-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.fr-CA-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.fr-CA-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.fr-CA-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.fr-CA-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.en-US-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.en-US-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.en-US-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.en-US-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.en-US-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.en-US-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.en-US-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.en-US-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.en-US-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.en-US-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.en-US-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.en-US-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.en-US-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.en-US-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.en-US-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.en-US-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.en-US-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.en-US-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.en-US-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.en-US-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.en-US-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.en-US-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.en-US-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.en-US-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.es-ES-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.es-ES-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.es-ES-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.es-ES-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.es-ES-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.es-ES-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.es-ES-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.es-ES-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.es-ES-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.es-ES-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.es-ES-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.es-ES-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.es-ES-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.es-ES-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.es-ES-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.es-ES-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.es-ES-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.es-ES-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.es-ES-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.es-ES-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.es-ES-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.es-ES-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.es-ES-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.es-ES-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.gu-IN-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.gu-IN-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.gu-IN-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.gu-IN-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.gu-IN-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.gu-IN-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.gu-IN-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.gu-IN-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.gu-IN-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.gu-IN-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.gu-IN-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.gu-IN-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.gu-IN-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.gu-IN-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.gu-IN-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.gu-IN-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.gu-IN-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.gu-IN-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.gu-IN-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.gu-IN-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.gu-IN-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.gu-IN-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.gu-IN-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.gu-IN-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.ja-JP-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.ja-JP-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.ja-JP-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.ja-JP-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.ja-JP-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.ja-JP-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.ja-JP-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.ja-JP-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.ja-JP-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.ja-JP-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.ja-JP-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.ja-JP-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.ja-JP-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.ja-JP-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.ja-JP-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.ja-JP-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.ja-JP-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.ja-JP-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.ja-JP-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.ja-JP-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.ja-JP-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.ja-JP-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.ja-JP-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.ja-JP-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.kn-IN-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.kn-IN-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.kn-IN-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.kn-IN-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.kn-IN-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.kn-IN-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.kn-IN-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.kn-IN-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.kn-IN-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.kn-IN-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.kn-IN-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.kn-IN-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.kn-IN-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.kn-IN-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.kn-IN-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.kn-IN-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.kn-IN-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.kn-IN-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.kn-IN-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.kn-IN-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.kn-IN-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.kn-IN-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.kn-IN-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.kn-IN-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.ml-IN-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.ml-IN-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.ml-IN-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.ml-IN-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.ml-IN-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.ml-IN-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.ml-IN-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.ml-IN-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.ml-IN-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.ml-IN-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.ml-IN-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.ml-IN-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.ml-IN-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.ml-IN-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.ml-IN-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.ml-IN-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.ml-IN-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.ml-IN-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.ml-IN-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.ml-IN-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.ml-IN-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.ml-IN-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.ml-IN-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.ml-IN-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.sv-SE-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.sv-SE-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.sv-SE-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.sv-SE-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.sv-SE-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.sv-SE-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.sv-SE-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.sv-SE-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.sv-SE-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.sv-SE-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.sv-SE-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.sv-SE-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.sv-SE-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.sv-SE-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.sv-SE-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.sv-SE-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.sv-SE-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.sv-SE-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.sv-SE-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.sv-SE-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.sv-SE-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.sv-SE-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.sv-SE-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.sv-SE-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.ta-IN-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.ta-IN-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.ta-IN-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.ta-IN-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.ta-IN-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.ta-IN-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.ta-IN-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.ta-IN-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.ta-IN-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.ta-IN-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.ta-IN-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.ta-IN-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.ta-IN-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.ta-IN-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.ta-IN-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.ta-IN-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.ta-IN-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.ta-IN-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.ta-IN-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.ta-IN-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.ta-IN-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.ta-IN-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.ta-IN-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.ta-IN-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.tr-TR-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.tr-TR-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.tr-TR-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.tr-TR-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.tr-TR-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.tr-TR-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.tr-TR-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.tr-TR-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.tr-TR-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.tr-TR-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.tr-TR-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.tr-TR-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.tr-TR-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.tr-TR-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.tr-TR-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.tr-TR-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.tr-TR-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.tr-TR-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.tr-TR-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.tr-TR-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.tr-TR-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.tr-TR-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.tr-TR-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.tr-TR-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.cs-CZ-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.cs-CZ-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.cs-CZ-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.cs-CZ-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.cs-CZ-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.cs-CZ-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.cs-CZ-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.cs-CZ-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.cs-CZ-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.cs-CZ-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.cs-CZ-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.cs-CZ-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.cs-CZ-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.cs-CZ-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.cs-CZ-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.cs-CZ-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.cs-CZ-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.cs-CZ-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.cs-CZ-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.cs-CZ-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.cs-CZ-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.cs-CZ-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.cs-CZ-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.cs-CZ-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.de-DE-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.de-DE-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.de-DE-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.de-DE-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.de-DE-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.de-DE-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.de-DE-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.de-DE-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.de-DE-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.de-DE-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.de-DE-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.de-DE-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.de-DE-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.de-DE-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.de-DE-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.de-DE-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.de-DE-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.de-DE-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.de-DE-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.de-DE-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.de-DE-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.de-DE-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.de-DE-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.de-DE-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.en-AU-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.en-AU-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.en-AU-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.en-AU-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.en-AU-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.en-AU-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.en-AU-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.en-AU-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.en-AU-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.en-AU-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.en-AU-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.en-AU-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.en-AU-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.en-AU-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.en-AU-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.en-AU-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.en-AU-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.en-AU-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.en-AU-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.en-AU-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.en-AU-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.en-AU-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.en-AU-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.en-AU-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.en-IN-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.en-IN-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.en-IN-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.en-IN-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.en-IN-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.en-IN-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.en-IN-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.en-IN-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.en-IN-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.en-IN-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.en-IN-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.en-IN-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.en-IN-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.en-IN-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.en-IN-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.en-IN-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.en-IN-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.en-IN-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.en-IN-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.en-IN-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.en-IN-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.en-IN-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.en-IN-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.en-IN-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.fr-FR-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.fr-FR-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.fr-FR-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.fr-FR-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.fr-FR-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.fr-FR-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.fr-FR-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.fr-FR-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.fr-FR-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.fr-FR-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.fr-FR-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.fr-FR-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.fr-FR-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.fr-FR-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.fr-FR-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.fr-FR-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.fr-FR-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.fr-FR-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.fr-FR-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.fr-FR-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.fr-FR-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.fr-FR-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.fr-FR-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.fr-FR-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.hi-IN-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.hi-IN-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.hi-IN-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.hi-IN-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.hi-IN-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.hi-IN-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.hi-IN-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.hi-IN-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.hi-IN-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.hi-IN-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.hi-IN-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.hi-IN-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.hi-IN-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.hi-IN-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.hi-IN-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.hi-IN-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.hi-IN-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.hi-IN-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.hi-IN-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.hi-IN-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.hi-IN-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.hi-IN-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.hi-IN-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.hi-IN-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.id-ID-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.id-ID-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.id-ID-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.id-ID-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.id-ID-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.id-ID-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.id-ID-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.id-ID-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.id-ID-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.id-ID-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.id-ID-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.id-ID-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.id-ID-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.id-ID-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.id-ID-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.id-ID-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.id-ID-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.id-ID-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.id-ID-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.id-ID-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.id-ID-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.id-ID-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.id-ID-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.id-ID-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.it-IT-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.it-IT-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.it-IT-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.it-IT-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.it-IT-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.it-IT-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.it-IT-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.it-IT-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.it-IT-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.it-IT-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.it-IT-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.it-IT-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.it-IT-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.it-IT-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.it-IT-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.it-IT-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.it-IT-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.it-IT-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.it-IT-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.it-IT-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.it-IT-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.it-IT-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.it-IT-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.it-IT-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.ko-KR-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.ko-KR-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.ko-KR-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.ko-KR-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.ko-KR-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.ko-KR-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.ko-KR-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.ko-KR-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.ko-KR-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.ko-KR-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.ko-KR-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.ko-KR-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.ko-KR-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.ko-KR-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.ko-KR-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.ko-KR-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.ko-KR-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.ko-KR-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.ko-KR-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.ko-KR-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.ko-KR-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.ko-KR-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.ko-KR-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.ko-KR-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.ru-RU-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.ru-RU-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.ru-RU-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.ru-RU-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.ru-RU-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.ru-RU-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.ru-RU-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.ru-RU-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.ru-RU-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.ru-RU-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.ru-RU-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.ru-RU-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.ru-RU-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.ru-RU-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.ru-RU-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.ru-RU-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.ru-RU-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.ru-RU-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.ru-RU-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.ru-RU-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.ru-RU-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.ru-RU-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.ru-RU-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.ru-RU-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.uk-UA-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.uk-UA-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.uk-UA-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.uk-UA-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.uk-UA-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.uk-UA-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.uk-UA-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.uk-UA-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.uk-UA-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.uk-UA-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.uk-UA-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.uk-UA-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.uk-UA-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.uk-UA-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.uk-UA-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.uk-UA-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.uk-UA-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.uk-UA-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.uk-UA-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.uk-UA-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.uk-UA-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.uk-UA-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.uk-UA-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.uk-UA-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.cmn-CN-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.cmn-CN-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.cmn-CN-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.cmn-CN-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.cmn-CN-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.cmn-CN-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.cmn-CN-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.cmn-CN-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.cmn-CN-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.cmn-CN-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.cmn-CN-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.cmn-CN-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.cmn-CN-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.cmn-CN-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.cmn-CN-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.cmn-CN-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.cmn-CN-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.cmn-CN-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.cmn-CN-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.cmn-CN-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.cmn-CN-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.cmn-CN-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.cmn-CN-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.cmn-CN-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.cmn-TW-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.cmn-TW-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.cmn-TW-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.cmn-TW-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.cmn-TW-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.cmn-TW-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.cmn-TW-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.cmn-TW-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.cmn-TW-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.cmn-TW-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.cmn-TW-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.cmn-TW-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.cmn-TW-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.cmn-TW-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.cmn-TW-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.cmn-TW-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.cmn-TW-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.cmn-TW-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.cmn-TW-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.cmn-TW-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.cmn-TW-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.cmn-TW-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.cmn-TW-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.cmn-TW-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.da-DK-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.da-DK-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.da-DK-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.da-DK-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.da-DK-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.da-DK-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.da-DK-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.da-DK-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.da-DK-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.da-DK-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.da-DK-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.da-DK-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.da-DK-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.da-DK-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.da-DK-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.da-DK-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.da-DK-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.da-DK-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.da-DK-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.da-DK-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.da-DK-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.da-DK-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.da-DK-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.da-DK-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.el-GR-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.el-GR-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.el-GR-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.el-GR-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.el-GR-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.el-GR-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.el-GR-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.el-GR-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.el-GR-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.el-GR-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.el-GR-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.el-GR-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.el-GR-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.el-GR-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.el-GR-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.el-GR-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.el-GR-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.el-GR-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.el-GR-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.el-GR-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.el-GR-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.el-GR-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.el-GR-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.el-GR-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.fil-PH-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.fil-PH-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.fil-PH-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.fil-PH-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.fil-PH-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.fil-PH-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.fil-PH-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.fil-PH-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.fil-PH-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.fil-PH-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.fil-PH-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.fil-PH-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.fil-PH-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.fil-PH-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.fil-PH-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.fil-PH-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.fil-PH-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.fil-PH-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.fil-PH-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.fil-PH-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.fil-PH-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.fil-PH-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.fil-PH-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.fil-PH-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.hu-HU-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.hu-HU-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.hu-HU-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.hu-HU-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.hu-HU-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.hu-HU-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.hu-HU-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.hu-HU-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.hu-HU-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.hu-HU-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.hu-HU-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.hu-HU-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.hu-HU-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.hu-HU-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.hu-HU-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.hu-HU-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.hu-HU-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.hu-HU-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.hu-HU-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.hu-HU-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.hu-HU-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.hu-HU-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.hu-HU-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.hu-HU-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.nb-NO-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.nb-NO-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.nb-NO-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.nb-NO-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.nb-NO-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.nb-NO-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.nb-NO-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.nb-NO-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.nb-NO-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.nb-NO-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.nb-NO-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.nb-NO-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.nb-NO-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.nb-NO-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.nb-NO-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.nb-NO-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.nb-NO-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.nb-NO-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.nb-NO-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.nb-NO-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.nb-NO-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.nb-NO-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.nb-NO-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.nb-NO-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.nl-NL-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.nl-NL-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.nl-NL-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.nl-NL-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/arrow.nl-NL-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.nl-NL-NEUTRAL--2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.nl-NL-NEUTRAL--2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.nl-NL-NEUTRAL--2-0.9_noisy_3.wav
# skipping out-wav/infineon.nl-NL-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.nl-NL-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.nl-NL-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.nl-NL-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/arrow.nl-NL-NEUTRAL--2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.nl-NL-NEUTRAL--2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.nl-NL-NEUTRAL--2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.nl-NL-NEUTRAL--2-1_noisy_3.wav
# skipping out-wav/infineon.nl-NL-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.nl-NL-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.nl-NL-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.nl-NL-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/arrow.nl-NL-NEUTRAL--2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.nl-NL-NEUTRAL--2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.nl-NL-NEUTRAL--2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.nl-NL-NEUTRAL--2-1.1_noisy_3.wav
# skipping out-wav/infineon.pt-PT-NEUTRAL--2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.pt-PT-NEUTRAL--2-0.9_noisy_1.wav
# ...
# skipping out-wav/infineon.pt-BR-MALE-2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.pt-BR-MALE-2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.pt-BR-MALE-2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.pt-BR-MALE-2-1_noisy_3.wav
# skipping out-wav/arrow.pt-BR-MALE-2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.pt-BR-MALE-2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.pt-BR-MALE-2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.pt-BR-MALE-2-1_noisy_3.wav
# skipping out-wav/infineon.pt-BR-MALE-2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.pt-BR-MALE-2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.pt-BR-MALE-2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.pt-BR-MALE-2-1.1_noisy_3.wav
# skipping out-wav/arrow.pt-BR-MALE-2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.pt-BR-MALE-2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.pt-BR-MALE-2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.pt-BR-MALE-2-1.1_noisy_3.wav
# skipping out-wav/infineon.ca-ES-MALE-2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.ca-ES-MALE-2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.ca-ES-MALE-2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.ca-ES-MALE-2-0.9_noisy_3.wav
# skipping out-wav/arrow.ca-ES-MALE-2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.ca-ES-MALE-2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.ca-ES-MALE-2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.ca-ES-MALE-2-0.9_noisy_3.wav
# skipping out-wav/infineon.ca-ES-MALE-2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.ca-ES-MALE-2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.ca-ES-MALE-2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.ca-ES-MALE-2-1_noisy_3.wav
# skipping out-wav/arrow.ca-ES-MALE-2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.ca-ES-MALE-2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.ca-ES-MALE-2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.ca-ES-MALE-2-1_noisy_3.wav
# skipping out-wav/infineon.ca-ES-MALE-2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.ca-ES-MALE-2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.ca-ES-MALE-2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.ca-ES-MALE-2-1.1_noisy_3.wav
# skipping out-wav/arrow.ca-ES-MALE-2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.ca-ES-MALE-2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.ca-ES-MALE-2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.ca-ES-MALE-2-1.1_noisy_3.wav
# skipping out-wav/infineon.yue-HK-MALE-2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.yue-HK-MALE-2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.yue-HK-MALE-2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.yue-HK-MALE-2-0.9_noisy_3.wav
# skipping out-wav/arrow.yue-HK-MALE-2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.yue-HK-MALE-2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.yue-HK-MALE-2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.yue-HK-MALE-2-0.9_noisy_3.wav
# skipping out-wav/infineon.yue-HK-MALE-2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.yue-HK-MALE-2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.yue-HK-MALE-2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.yue-HK-MALE-2-1_noisy_3.wav
# skipping out-wav/arrow.yue-HK-MALE-2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.yue-HK-MALE-2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.yue-HK-MALE-2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.yue-HK-MALE-2-1_noisy_3.wav
# skipping out-wav/infineon.yue-HK-MALE-2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.yue-HK-MALE-2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.yue-HK-MALE-2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.yue-HK-MALE-2-1.1_noisy_3.wav
# skipping out-wav/arrow.yue-HK-MALE-2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.yue-HK-MALE-2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.yue-HK-MALE-2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.yue-HK-MALE-2-1.1_noisy_3.wav
# skipping out-wav/infineon.af-ZA-MALE-2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.af-ZA-MALE-2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.af-ZA-MALE-2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.af-ZA-MALE-2-0.9_noisy_3.wav
# skipping out-wav/arrow.af-ZA-MALE-2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.af-ZA-MALE-2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.af-ZA-MALE-2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.af-ZA-MALE-2-0.9_noisy_3.wav
# skipping out-wav/infineon.af-ZA-MALE-2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.af-ZA-MALE-2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.af-ZA-MALE-2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.af-ZA-MALE-2-1_noisy_3.wav
# skipping out-wav/arrow.af-ZA-MALE-2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.af-ZA-MALE-2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.af-ZA-MALE-2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.af-ZA-MALE-2-1_noisy_3.wav
# skipping out-wav/infineon.af-ZA-MALE-2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.af-ZA-MALE-2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.af-ZA-MALE-2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.af-ZA-MALE-2-1.1_noisy_3.wav
# skipping out-wav/arrow.af-ZA-MALE-2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.af-ZA-MALE-2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.af-ZA-MALE-2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.af-ZA-MALE-2-1.1_noisy_3.wav
# skipping out-wav/infineon.bg-BG-MALE-2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.bg-BG-MALE-2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.bg-BG-MALE-2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.bg-BG-MALE-2-0.9_noisy_3.wav
# skipping out-wav/arrow.bg-BG-MALE-2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.bg-BG-MALE-2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.bg-BG-MALE-2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.bg-BG-MALE-2-0.9_noisy_3.wav
# skipping out-wav/infineon.bg-BG-MALE-2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.bg-BG-MALE-2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.bg-BG-MALE-2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.bg-BG-MALE-2-1_noisy_3.wav
# skipping out-wav/arrow.bg-BG-MALE-2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.bg-BG-MALE-2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.bg-BG-MALE-2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.bg-BG-MALE-2-1_noisy_3.wav
# skipping out-wav/infineon.bg-BG-MALE-2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.bg-BG-MALE-2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.bg-BG-MALE-2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.bg-BG-MALE-2-1.1_noisy_3.wav
# skipping out-wav/arrow.bg-BG-MALE-2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.bg-BG-MALE-2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.bg-BG-MALE-2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.bg-BG-MALE-2-1.1_noisy_3.wav
# skipping out-wav/infineon.lv-LV-MALE-2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.lv-LV-MALE-2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.lv-LV-MALE-2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.lv-LV-MALE-2-0.9_noisy_3.wav
# skipping out-wav/arrow.lv-LV-MALE-2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.lv-LV-MALE-2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.lv-LV-MALE-2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.lv-LV-MALE-2-0.9_noisy_3.wav
# skipping out-wav/infineon.lv-LV-MALE-2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.lv-LV-MALE-2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.lv-LV-MALE-2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.lv-LV-MALE-2-1_noisy_3.wav
# skipping out-wav/arrow.lv-LV-MALE-2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.lv-LV-MALE-2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.lv-LV-MALE-2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.lv-LV-MALE-2-1_noisy_3.wav
# skipping out-wav/infineon.lv-LV-MALE-2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.lv-LV-MALE-2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.lv-LV-MALE-2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.lv-LV-MALE-2-1.1_noisy_3.wav
# skipping out-wav/arrow.lv-LV-MALE-2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.lv-LV-MALE-2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.lv-LV-MALE-2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.lv-LV-MALE-2-1.1_noisy_3.wav
# skipping out-wav/infineon.ro-RO-MALE-2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.ro-RO-MALE-2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.ro-RO-MALE-2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.ro-RO-MALE-2-0.9_noisy_3.wav
# skipping out-wav/arrow.ro-RO-MALE-2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.ro-RO-MALE-2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.ro-RO-MALE-2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.ro-RO-MALE-2-0.9_noisy_3.wav
# skipping out-wav/infineon.ro-RO-MALE-2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.ro-RO-MALE-2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.ro-RO-MALE-2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.ro-RO-MALE-2-1_noisy_3.wav
# skipping out-wav/arrow.ro-RO-MALE-2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.ro-RO-MALE-2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.ro-RO-MALE-2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.ro-RO-MALE-2-1_noisy_3.wav
# skipping out-wav/infineon.ro-RO-MALE-2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.ro-RO-MALE-2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.ro-RO-MALE-2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.ro-RO-MALE-2-1.1_noisy_3.wav
# skipping out-wav/arrow.ro-RO-MALE-2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.ro-RO-MALE-2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.ro-RO-MALE-2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.ro-RO-MALE-2-1.1_noisy_3.wav
# skipping out-wav/infineon.sr-RS-MALE-2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.sr-RS-MALE-2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.sr-RS-MALE-2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.sr-RS-MALE-2-0.9_noisy_3.wav
# skipping out-wav/arrow.sr-RS-MALE-2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.sr-RS-MALE-2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.sr-RS-MALE-2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.sr-RS-MALE-2-0.9_noisy_3.wav
# skipping out-wav/infineon.sr-RS-MALE-2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.sr-RS-MALE-2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.sr-RS-MALE-2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.sr-RS-MALE-2-1_noisy_3.wav
# skipping out-wav/arrow.sr-RS-MALE-2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.sr-RS-MALE-2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.sr-RS-MALE-2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.sr-RS-MALE-2-1_noisy_3.wav
# skipping out-wav/infineon.sr-RS-MALE-2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.sr-RS-MALE-2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.sr-RS-MALE-2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.sr-RS-MALE-2-1.1_noisy_3.wav
# skipping out-wav/arrow.sr-RS-MALE-2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.sr-RS-MALE-2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.sr-RS-MALE-2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.sr-RS-MALE-2-1.1_noisy_3.wav
# skipping out-wav/infineon.th-TH-MALE-2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.th-TH-MALE-2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.th-TH-MALE-2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.th-TH-MALE-2-0.9_noisy_3.wav
# skipping out-wav/arrow.th-TH-MALE-2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.th-TH-MALE-2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.th-TH-MALE-2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.th-TH-MALE-2-0.9_noisy_3.wav
# skipping out-wav/infineon.th-TH-MALE-2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.th-TH-MALE-2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.th-TH-MALE-2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.th-TH-MALE-2-1_noisy_3.wav
# skipping out-wav/arrow.th-TH-MALE-2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.th-TH-MALE-2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.th-TH-MALE-2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.th-TH-MALE-2-1_noisy_3.wav
# skipping out-wav/infineon.th-TH-MALE-2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.th-TH-MALE-2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.th-TH-MALE-2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.th-TH-MALE-2-1.1_noisy_3.wav
# skipping out-wav/arrow.th-TH-MALE-2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.th-TH-MALE-2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.th-TH-MALE-2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.th-TH-MALE-2-1.1_noisy_3.wav
# skipping out-wav/infineon.te-IN-MALE-2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.te-IN-MALE-2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.te-IN-MALE-2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.te-IN-MALE-2-0.9_noisy_3.wav
# skipping out-wav/arrow.te-IN-MALE-2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.te-IN-MALE-2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.te-IN-MALE-2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.te-IN-MALE-2-0.9_noisy_3.wav
# skipping out-wav/infineon.te-IN-MALE-2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.te-IN-MALE-2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.te-IN-MALE-2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.te-IN-MALE-2-1_noisy_3.wav
# skipping out-wav/arrow.te-IN-MALE-2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.te-IN-MALE-2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.te-IN-MALE-2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.te-IN-MALE-2-1_noisy_3.wav
# skipping out-wav/infineon.te-IN-MALE-2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.te-IN-MALE-2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.te-IN-MALE-2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.te-IN-MALE-2-1.1_noisy_3.wav
# skipping out-wav/arrow.te-IN-MALE-2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.te-IN-MALE-2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.te-IN-MALE-2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.te-IN-MALE-2-1.1_noisy_3.wav
# skipping out-wav/infineon.is-IS-MALE-2-0.9.tts.wav
# Saved mixed audio to out-noisy/infineon.is-IS-MALE-2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.is-IS-MALE-2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.is-IS-MALE-2-0.9_noisy_3.wav
# skipping out-wav/arrow.is-IS-MALE-2-0.9.tts.wav
# Saved mixed audio to out-noisy/arrow.is-IS-MALE-2-0.9_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.is-IS-MALE-2-0.9_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.is-IS-MALE-2-0.9_noisy_3.wav
# skipping out-wav/infineon.is-IS-MALE-2-1.tts.wav
# Saved mixed audio to out-noisy/infineon.is-IS-MALE-2-1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.is-IS-MALE-2-1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.is-IS-MALE-2-1_noisy_3.wav
# skipping out-wav/arrow.is-IS-MALE-2-1.tts.wav
# Saved mixed audio to out-noisy/arrow.is-IS-MALE-2-1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.is-IS-MALE-2-1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.is-IS-MALE-2-1_noisy_3.wav
# skipping out-wav/infineon.is-IS-MALE-2-1.1.tts.wav
# Saved mixed audio to out-noisy/infineon.is-IS-MALE-2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/infineon.is-IS-MALE-2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/infineon.is-IS-MALE-2-1.1_noisy_3.wav
# skipping out-wav/arrow.is-IS-MALE-2-1.1.tts.wav
# Saved mixed audio to out-noisy/arrow.is-IS-MALE-2-1.1_noisy_1.wav
# Saved mixed audio to out-noisy/arrow.is-IS-MALE-2-1.1_noisy_2.wav
# Saved mixed audio to out-noisy/arrow.is-IS-MALE-2-1.1_noisy_3.wav
# Done text-to-speeching

# %%
from pydub import AudioSegment
import random
import os, requests, io

# specify the input file path

# specify the number of samples you want to extract
num_samples = 400

# specify the length of each sample in milliseconds
sample_length_ms = 1000

# open the input file
# Creative commons background noise from freesound.org:https://freesound.org/people/Astounded/sounds/483561/
noise_url = 'https://cdn.freesound.org/previews/483/483561_10201334-lq.ogg'

# Check if output directory exists and create it if it doesn't
if not os.path.exists('background'):
    os.makedirs('background')
# Download background noise file
response = requests.get(noise_url)
response.raise_for_status()
audio = AudioSegment.from_file(io.BytesIO(response.content), format='ogg')

# get the duration of the audio in milliseconds
audio_duration_ms = len(audio)

# calculate the maximum start time for each sample
max_start_time_ms = audio_duration_ms - sample_length_ms

# initialize a list to hold the extracted samples
samples = []

# extract X number of 1-second samples
for i in range(num_samples):
    # generate a random start time for each sample
    start_time_ms = random.randint(0, max_start_time_ms)
    end_time_ms = start_time_ms + sample_length_ms
    
    # extract the sample
    sample = audio[start_time_ms:end_time_ms]
    
    # append the sample to the list
    samples.append(sample)
    
# export each sample to a WAV file
for i, sample in enumerate(samples):
    output_file_path = f"background/background.sample_{i+1}.wav"
    sample.export(output_file_path, format="wav")
